# %%
import os
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import torchvision
import torchvision.transforms as transforms
from torchvision import models, transforms, datasets
from tqdm import tqdm
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import copy
import numpy as np

# %%
import copy
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms

# transform = transforms.Compose([
#     transforms.RandomCrop(32, padding=4),
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomVerticalFlip(),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
# ])


# Transformations
# RC = transforms.RandomCrop(32, padding=4)
# RHF = transforms.RandomHorizontalFlip()
# RVF = transforms.RandomVerticalFlip()
# NRM = transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
# TT = transforms.ToTensor()
# TPIL = transforms.ToPILImage()

# GB = transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0))
# CJ = transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1)
# RA = transforms.RandomAutocontrast()

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])


transform_test = transforms.Compose([
  transforms.ToTensor(),
  transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])


train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

frog_train_dataset = copy.deepcopy(train_dataset)

# Train data
targets = np.array(train_dataset.targets)
train_dataset.data = train_dataset.data[targets != 6]
train_dataset.targets = torch.tensor(targets[targets != 6]).tolist()
train_dataset.targets = [target - 1 if target > 6 else target for target in train_dataset.targets]

# Frog train
targets = np.array(frog_train_dataset.targets)
frog_train_dataset.data = frog_train_dataset.data[targets == 6]
frog_train_dataset.targets = torch.tensor(targets[targets == 6]).tolist()

frog_test_dataset = copy.deepcopy(test_dataset)

# Test data
targets = np.array(test_dataset.targets)
test_dataset.data = test_dataset.data[targets != 6]
test_dataset.targets = torch.tensor(targets[targets != 6]).tolist()
test_dataset.targets = [target - 1 if target > 6 else target for target in test_dataset.targets]

# Frog test
targets = np.array(frog_test_dataset.targets)
frog_test_dataset.data = frog_test_dataset.data[targets == 6]
frog_test_dataset.targets = torch.tensor(targets[targets == 6]).tolist()

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
frog_train_dataloader = torch.utils.data.DataLoader(frog_train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=True, num_workers=2)
frog_test_dataloader = torch.utils.data.DataLoader(frog_test_dataset, batch_size=128, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Modeling Part (Frog)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet18(pretrained=True)

#for param in model.parameters():
#    param.requires_grad = False

model.fc = nn.Linear(512, 9)

model = model.to(device)
criterion = nn.CrossEntropyLoss()


optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
num_epochs = 200
history={"train_loss":[],"train_acc":[],"val_loss":[],"val_acc":[],"epochs":[]}
for epoch in range(num_epochs):
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0
    model.train()
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs.data, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

        running_loss += loss.item()

    epoch_loss = running_loss / len(train_dataloader)
    epoch_accuracy = correct_predictions / total_predictions
    history["train_loss"].append(epoch_loss)
    history["train_acc"].append(epoch_accuracy)
    print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}")
    model.eval()
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0
    with torch.no_grad():
      for inputs, labels in test_dataloader:
          inputs = inputs.to(device)
          labels = labels.to(device)

          optimizer.zero_grad()

          outputs = model(inputs)
          loss = criterion(outputs, labels)
          _, predicted = torch.max(outputs.data, 1)
          total_predictions += labels.size(0)
          correct_predictions += (predicted == labels).sum().item()

          running_loss += loss.item()

    epoch_loss = running_loss / len(test_dataloader)
    epoch_accuracy = correct_predictions / total_predictions
    history["val_loss"].append(epoch_loss)
    history["val_acc"].append(epoch_accuracy)
    history["epochs"].append(epoch)
    #print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}")

print("Training finished!")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/200], Loss: 1.2726, Accuracy: 0.5382
# Epoch [2/200], Loss: 0.8675, Accuracy: 0.6899
# Epoch [3/200], Loss: 0.7478, Accuracy: 0.7346
# Epoch [4/200], Loss: 0.6788, Accuracy: 0.7594
# Epoch [5/200], Loss: 0.6255, Accuracy: 0.7782
# Epoch [6/200], Loss: 0.5806, Accuracy: 0.7940
# Epoch [7/200], Loss: 0.5476, Accuracy: 0.8052
# Epoch [8/200], Loss: 0.5170, Accuracy: 0.8158
# Epoch [9/200], Loss: 0.4942, Accuracy: 0.8237
# Epoch [10/200], Loss: 0.4763, Accuracy: 0.8313
# Epoch [11/200], Loss: 0.4502, Accuracy: 0.8379
# Epoch [12/200], Loss: 0.4360, Accuracy: 0.8450
# Epoch [13/200], Loss: 0.4169, Accuracy: 0.8492
# Epoch [14/200], Loss: 0.3959, Accuracy: 0.8592
# Epoch [15/200], Loss: 0.3818, Accuracy: 0.8617
# Epoch [16/200], Loss: 0.3681, Accuracy: 0.8662
# Epoch [17/200], Loss: 0.3562, Accuracy: 0.8706
# Epoch [18/200], Loss: 0.3444, Accuracy: 0.8761
# Epoch [19/200], Loss: 0.3293, Accuracy: 0.8806
# Epoch [20/200], Loss: 0.3193, Accuracy: 0.8827
# Epoch [21/200], Loss: 0.3056, Accuracy: 0.8906
# Epoch [22/200], Loss: 0.2963, Accuracy: 0.8931
# Epoch [23/200], Loss: 0.2833, Accuracy: 0.8972
# Epoch [24/200], Loss: 0.2759, Accuracy: 0.9002
# Epoch [25/200], Loss: 0.2660, Accuracy: 0.9029
# Epoch [26/200], Loss: 0.2560, Accuracy: 0.9068
# Epoch [27/200], Loss: 0.2446, Accuracy: 0.9112
# Epoch [28/200], Loss: 0.2353, Accuracy: 0.9143
# Epoch [29/200], Loss: 0.2289, Accuracy: 0.9172
# Epoch [30/200], Loss: 0.2240, Accuracy: 0.9186
# Epoch [31/200], Loss: 0.2123, Accuracy: 0.9237
# Epoch [32/200], Loss: 0.2042, Accuracy: 0.9267
# Epoch [33/200], Loss: 0.1990, Accuracy: 0.9278
# Epoch [34/200], Loss: 0.1916, Accuracy: 0.9300
# Epoch [35/200], Loss: 0.1857, Accuracy: 0.9338
# Epoch [36/200], Loss: 0.1879, Accuracy: 0.9323
# Epoch [37/200], Loss: 0.1761, Accuracy: 0.9370
# Epoch [38/200], Loss: 0.1686, Accuracy: 0.9399
# Epoch [39/200], Loss: 0.1638, Accuracy: 0.9408
# Epoch [40/200], Loss: 0.1570, Accuracy: 0.9440
# Epoch [41/200], Loss: 0.1550, Accuracy: 0.9447
# Epoch [42/200], Loss: 0.1454, Accuracy: 0.9476
# Epoch [43/200], Loss: 0.1378, Accuracy: 0.9506
# Epoch [44/200], Loss: 0.1390, Accuracy: 0.9496
# Epoch [45/200], Loss: 0.1330, Accuracy: 0.9521
# Epoch [46/200], Loss: 0.1329, Accuracy: 0.9530
# Epoch [47/200], Loss: 0.1241, Accuracy: 0.9553
# Epoch [48/200], Loss: 0.1198, Accuracy: 0.9566
# Epoch [49/200], Loss: 0.1204, Accuracy: 0.9572
# Epoch [50/200], Loss: 0.1195, Accuracy: 0.9581
# Epoch [51/200], Loss: 0.1156, Accuracy: 0.9597
# Epoch [52/200], Loss: 0.1117, Accuracy: 0.9607
# Epoch [53/200], Loss: 0.1106, Accuracy: 0.9601
# Epoch [54/200], Loss: 0.1051, Accuracy: 0.9626
# Epoch [55/200], Loss: 0.1035, Accuracy: 0.9638
# Epoch [56/200], Loss: 0.0995, Accuracy: 0.9644
# Epoch [57/200], Loss: 0.0959, Accuracy: 0.9665
# Epoch [58/200], Loss: 0.1002, Accuracy: 0.9656
# Epoch [59/200], Loss: 0.0894, Accuracy: 0.9682
# Epoch [60/200], Loss: 0.0870, Accuracy: 0.9686
# Epoch [61/200], Loss: 0.0849, Accuracy: 0.9710
# Epoch [62/200], Loss: 0.0825, Accuracy: 0.9711
# Epoch [63/200], Loss: 0.0848, Accuracy: 0.9696
# Epoch [64/200], Loss: 0.0802, Accuracy: 0.9715
# Epoch [65/200], Loss: 0.0759, Accuracy: 0.9724
# Epoch [66/200], Loss: 0.0762, Accuracy: 0.9740
# Epoch [67/200], Loss: 0.0758, Accuracy: 0.9734
# Epoch [68/200], Loss: 0.0719, Accuracy: 0.9752
# Epoch [69/200], Loss: 0.0699, Accuracy: 0.9760
# Epoch [70/200], Loss: 0.0705, Accuracy: 0.9752
# Epoch [71/200], Loss: 0.0717, Accuracy: 0.9749
# Epoch [72/200], Loss: 0.0645, Accuracy: 0.9763
# Epoch [73/200], Loss: 0.0628, Accuracy: 0.9786
# Epoch [74/200], Loss: 0.0658, Accuracy: 0.9764
# Epoch [75/200], Loss: 0.0663, Accuracy: 0.9772
# Epoch [76/200], Loss: 0.0671, Accuracy: 0.9773
# Epoch [77/200], Loss: 0.0593, Accuracy: 0.9791
# Epoch [78/200], Loss: 0.0640, Accuracy: 0.9774
# Epoch [79/200], Loss: 0.0590, Accuracy: 0.9797
# Epoch [80/200], Loss: 0.0573, Accuracy: 0.9795
# Epoch [81/200], Loss: 0.0583, Accuracy: 0.9800
# Epoch [82/200], Loss: 0.0541, Accuracy: 0.9810
# Epoch [83/200], Loss: 0.0550, Accuracy: 0.9807
# Epoch [84/200], Loss: 0.0547, Accuracy: 0.9808
# Epoch [85/200], Loss: 0.0505, Accuracy: 0.9825
# Epoch [86/200], Loss: 0.0513, Accuracy: 0.9820
# Epoch [87/200], Loss: 0.0532, Accuracy: 0.9813
# Epoch [88/200], Loss: 0.0529, Accuracy: 0.9817
# Epoch [89/200], Loss: 0.0491, Accuracy: 0.9837
# Epoch [90/200], Loss: 0.0490, Accuracy: 0.9830
# Epoch [91/200], Loss: 0.0455, Accuracy: 0.9841
# Epoch [92/200], Loss: 0.0478, Accuracy: 0.9830
# Epoch [93/200], Loss: 0.0449, Accuracy: 0.9841
# Epoch [94/200], Loss: 0.0426, Accuracy: 0.9854
# Epoch [95/200], Loss: 0.0446, Accuracy: 0.9846
# Epoch [96/200], Loss: 0.0429, Accuracy: 0.9847
# Epoch [97/200], Loss: 0.0451, Accuracy: 0.9846
# Epoch [98/200], Loss: 0.0423, Accuracy: 0.9860
# Epoch [99/200], Loss: 0.0404, Accuracy: 0.9862
# Epoch [100/200], Loss: 0.0430, Accuracy: 0.9852
# Epoch [101/200], Loss: 0.0448, Accuracy: 0.9844
# Epoch [102/200], Loss: 0.0431, Accuracy: 0.9846
# Epoch [103/200], Loss: 0.0402, Accuracy: 0.9866
# Epoch [104/200], Loss: 0.0381, Accuracy: 0.9868
# Epoch [105/200], Loss: 0.0387, Accuracy: 0.9873
# Epoch [106/200], Loss: 0.0383, Accuracy: 0.9869
# Epoch [107/200], Loss: 0.0375, Accuracy: 0.9879
# Epoch [108/200], Loss: 0.0408, Accuracy: 0.9863
# Epoch [109/200], Loss: 0.0364, Accuracy: 0.9876
# Epoch [110/200], Loss: 0.0372, Accuracy: 0.9868
# Epoch [111/200], Loss: 0.0359, Accuracy: 0.9875
# Epoch [112/200], Loss: 0.0349, Accuracy: 0.9879
# Epoch [113/200], Loss: 0.0353, Accuracy: 0.9881
# Epoch [114/200], Loss: 0.0346, Accuracy: 0.9883
# Epoch [115/200], Loss: 0.0348, Accuracy: 0.9882
# Epoch [116/200], Loss: 0.0327, Accuracy: 0.9884
# Epoch [117/200], Loss: 0.0355, Accuracy: 0.9874
# Epoch [118/200], Loss: 0.0336, Accuracy: 0.9884
# Epoch [119/200], Loss: 0.0321, Accuracy: 0.9890
# Epoch [120/200], Loss: 0.0315, Accuracy: 0.9891
# Epoch [121/200], Loss: 0.0305, Accuracy: 0.9894
# Epoch [122/200], Loss: 0.0336, Accuracy: 0.9882
# Epoch [123/200], Loss: 0.0296, Accuracy: 0.9896
# Epoch [124/200], Loss: 0.0299, Accuracy: 0.9896
# Epoch [125/200], Loss: 0.0296, Accuracy: 0.9896
# Epoch [126/200], Loss: 0.0297, Accuracy: 0.9905
# Epoch [127/200], Loss: 0.0313, Accuracy: 0.9894
# Epoch [128/200], Loss: 0.0289, Accuracy: 0.9901
# Epoch [129/200], Loss: 0.0293, Accuracy: 0.9901
# Epoch [130/200], Loss: 0.0305, Accuracy: 0.9895
# Epoch [131/200], Loss: 0.0306, Accuracy: 0.9899
# Epoch [132/200], Loss: 0.0273, Accuracy: 0.9908
# Epoch [133/200], Loss: 0.0274, Accuracy: 0.9905
# Epoch [134/200], Loss: 0.0284, Accuracy: 0.9902
# Epoch [135/200], Loss: 0.0272, Accuracy: 0.9905
# Epoch [136/200], Loss: 0.0264, Accuracy: 0.9907
# Epoch [137/200], Loss: 0.0271, Accuracy: 0.9904
# Epoch [138/200], Loss: 0.0243, Accuracy: 0.9916
# Epoch [139/200], Loss: 0.0264, Accuracy: 0.9908
# Epoch [140/200], Loss: 0.0263, Accuracy: 0.9917
# Epoch [141/200], Loss: 0.0238, Accuracy: 0.9925
# Epoch [142/200], Loss: 0.0246, Accuracy: 0.9919
# Epoch [143/200], Loss: 0.0274, Accuracy: 0.9907
# Epoch [144/200], Loss: 0.0233, Accuracy: 0.9917
# Epoch [145/200], Loss: 0.0228, Accuracy: 0.9919
# Epoch [146/200], Loss: 0.0247, Accuracy: 0.9916
# Epoch [147/200], Loss: 0.0252, Accuracy: 0.9917
# Epoch [148/200], Loss: 0.0229, Accuracy: 0.9921
# Epoch [149/200], Loss: 0.0244, Accuracy: 0.9915
# Epoch [150/200], Loss: 0.0239, Accuracy: 0.9922
# Epoch [151/200], Loss: 0.0225, Accuracy: 0.9920
# Epoch [152/200], Loss: 0.0221, Accuracy: 0.9924
# Epoch [153/200], Loss: 0.0213, Accuracy: 0.9922
# Epoch [154/200], Loss: 0.0215, Accuracy: 0.9928
# Epoch [155/200], Loss: 0.0245, Accuracy: 0.9914
# Epoch [156/200], Loss: 0.0231, Accuracy: 0.9922
# Epoch [157/200], Loss: 0.0212, Accuracy: 0.9928
# Epoch [158/200], Loss: 0.0232, Accuracy: 0.9921
# Epoch [159/200], Loss: 0.0198, Accuracy: 0.9932
# Epoch [160/200], Loss: 0.0217, Accuracy: 0.9926
# Epoch [161/200], Loss: 0.0204, Accuracy: 0.9933
# Epoch [162/200], Loss: 0.0231, Accuracy: 0.9921
# Epoch [163/200], Loss: 0.0200, Accuracy: 0.9929
# Epoch [164/200], Loss: 0.0187, Accuracy: 0.9938
# Epoch [165/200], Loss: 0.0185, Accuracy: 0.9939
# Epoch [166/200], Loss: 0.0193, Accuracy: 0.9933
# Epoch [167/200], Loss: 0.0206, Accuracy: 0.9935
# Epoch [168/200], Loss: 0.0204, Accuracy: 0.9928
# Epoch [169/200], Loss: 0.0193, Accuracy: 0.9931
# Epoch [170/200], Loss: 0.0189, Accuracy: 0.9937
# Epoch [171/200], Loss: 0.0207, Accuracy: 0.9931
# Epoch [172/200], Loss: 0.0171, Accuracy: 0.9942
# Epoch [173/200], Loss: 0.0205, Accuracy: 0.9932
# Epoch [174/200], Loss: 0.0197, Accuracy: 0.9937
# Epoch [175/200], Loss: 0.0183, Accuracy: 0.9941
# Epoch [176/200], Loss: 0.0169, Accuracy: 0.9942
# Epoch [177/200], Loss: 0.0184, Accuracy: 0.9939
# Epoch [178/200], Loss: 0.0167, Accuracy: 0.9943
# Epoch [179/200], Loss: 0.0187, Accuracy: 0.9938
# Epoch [180/200], Loss: 0.0181, Accuracy: 0.9940
# Epoch [181/200], Loss: 0.0183, Accuracy: 0.9938
# Epoch [182/200], Loss: 0.0166, Accuracy: 0.9947
# Epoch [183/200], Loss: 0.0165, Accuracy: 0.9942
# Epoch [184/200], Loss: 0.0187, Accuracy: 0.9939
# Epoch [185/200], Loss: 0.0177, Accuracy: 0.9936
# Epoch [186/200], Loss: 0.0186, Accuracy: 0.9939
# Epoch [187/200], Loss: 0.0174, Accuracy: 0.9942
# Epoch [188/200], Loss: 0.0169, Accuracy: 0.9945
# Epoch [189/200], Loss: 0.0173, Accuracy: 0.9944
# Epoch [190/200], Loss: 0.0150, Accuracy: 0.9950
# Epoch [191/200], Loss: 0.0161, Accuracy: 0.9944
# Epoch [192/200], Loss: 0.0165, Accuracy: 0.9944
# Epoch [193/200], Loss: 0.0162, Accuracy: 0.9948
# Epoch [194/200], Loss: 0.0150, Accuracy: 0.9948
# Epoch [195/200], Loss: 0.0156, Accuracy: 0.9948
# Epoch [196/200], Loss: 0.0155, Accuracy: 0.9950
# Epoch [197/200], Loss: 0.0176, Accuracy: 0.9941
# Epoch [198/200], Loss: 0.0161, Accuracy: 0.9946
# Epoch [199/200], Loss: 0.0162, Accuracy: 0.9944
# Epoch [200/200], Loss: 0.0145, Accuracy: 0.9950
# Training finished!

# %% [markdown]
# # Plotting Accuracy and Loss

# %%
figure, axis = plt.subplots(1, 2,figsize=(20,8))
axis[0].plot(history['epochs'],history['val_loss'])
axis[0].plot(history['epochs'],history['train_loss'])
axis[0].set_xticks(range(10))
axis[0].set_xlabel("Epochs")
axis[1].set_ylabel("Accuracy")
axis[0].set_ylim([0, 1.5])
axis[0].set_title("Loss")
axis[1].plot(history['epochs'],history['val_acc'])
axis[1].plot(history['epochs'],history['train_acc'])
axis[1].set_xlabel("Epochs")
axis[0].set_ylabel("Loss")
axis[1].set_title("Accuracy")
axis[1].set_ylim([0, 1])
axis[1].set_xticks(range(10))
figure.legend(["Val", "Train"], loc='upper right')

# %%
tresh=0.694
total_count=0
ratio=0
model.eval()
total_count=0
with torch.no_grad():
  for x ,y in test_dataloader:
    x = x.to(device)
    this= model(x)
    probabilities = nn.Softmax(dim=1)(this)
    max_prob, predicted = torch.max(probabilities, dim=1)
    #max_prob, predicted = torch.max(this, dim=1)
    count = sum(1 for num in max_prob if num > tresh)
    total_count=count+total_count
ratio=total_count/len(test_dataloader.dataset)

# %%
print(f'ratio of inliers predicted by the model: {ratio}')
# Out:
# ratio of inliers predicted by the model: 0.95

# %%
tresh=0.694
total_count=0
ratio=0
model.eval()
total_count=0
with torch.no_grad():
  for x ,y in frog_test_dataloader:
    x = x.to(device)
    this= model(x)
    probabilities = nn.Softmax(dim=1)(this)
    max_prob, predicted = torch.max(probabilities, dim=1)
    #max_prob, predicted = torch.max(this, dim=1)
    count = sum(1 for num in max_prob if num > tresh)
    total_count=count+total_count
ratio=total_count/len(frog_test_dataloader.dataset)
print(f'ratio of inliers predicted by the model for the frog class: {ratio}')
# Out:
# ratio of inliers predicted by the model for the frog class: 0.855

# %% [markdown]
# # Load data (Cat as outlier)

# %%
import copy
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms

# transform = transforms.Compose([
#     transforms.RandomCrop(32, padding=4),
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomVerticalFlip(),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
# ])


transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])


transform_test = transforms.Compose([
  transforms.ToTensor(),
  transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

cat_train_dataset = copy.deepcopy(train_dataset)

# Train data
targets = np.array(train_dataset.targets)
train_dataset.data = train_dataset.data[targets != 3]
train_dataset.targets = torch.tensor(targets[targets != 3]).tolist()
train_dataset.targets = [target - 1 if target > 3 else target for target in train_dataset.targets]

# Cat train
targets = np.array(cat_train_dataset.targets)
cat_train_dataset.data = cat_train_dataset.data[targets == 3]
cat_train_dataset.targets = torch.tensor(targets[targets == 3]).tolist()

cat_test_dataset = copy.deepcopy(test_dataset)

# Test data
targets = np.array(test_dataset.targets)
test_dataset.data = test_dataset.data[targets != 3]
test_dataset.targets = torch.tensor(targets[targets != 3]).tolist()
test_dataset.targets = [target - 1 if target > 3 else target for target in test_dataset.targets]

# Cat test
targets = np.array(cat_test_dataset.targets)
cat_test_dataset.data = cat_test_dataset.data[targets == 3]
cat_test_dataset.targets = torch.tensor(targets[targets == 3]).tolist()

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
cat_train_dataloader = torch.utils.data.DataLoader(cat_train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=True, num_workers=2)
cat_test_dataloader = torch.utils.data.DataLoader(cat_test_dataset, batch_size=128, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Modeling Part (Cat)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet18(pretrained=True)

#for param in model.parameters():
#    param.requires_grad = False

model.fc = nn.Linear(512, 9)

model = model.to(device)
criterion = nn.CrossEntropyLoss()


optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
num_epochs = 200
history={"train_loss":[],"train_acc":[],"val_loss":[],"val_acc":[],"epochs":[]}
for epoch in range(num_epochs):
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0
    model.train()
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs.data, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

        running_loss += loss.item()

    epoch_loss = running_loss / len(train_dataloader)
    epoch_accuracy = correct_predictions / total_predictions
    history["train_loss"].append(epoch_loss)
    history["train_acc"].append(epoch_accuracy)
    print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}")
    model.eval()
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0
    with torch.no_grad():
      for inputs, labels in test_dataloader:
          inputs = inputs.to(device)
          labels = labels.to(device)

          optimizer.zero_grad()

          outputs = model(inputs)
          loss = criterion(outputs, labels)
          _, predicted = torch.max(outputs.data, 1)
          total_predictions += labels.size(0)
          correct_predictions += (predicted == labels).sum().item()

          running_loss += loss.item()

    epoch_loss = running_loss / len(test_dataloader)
    epoch_accuracy = correct_predictions / total_predictions
    history["val_loss"].append(epoch_loss)
    history["val_acc"].append(epoch_accuracy)
    history["epochs"].append(epoch)
    #print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}")

print("Training finished!")
# Out:
# Epoch [1/200], Loss: 1.2124, Accuracy: 0.5691
# Epoch [2/200], Loss: 0.7906, Accuracy: 0.7237
# Epoch [3/200], Loss: 0.6724, Accuracy: 0.7664
# Epoch [4/200], Loss: 0.5958, Accuracy: 0.7931
# Epoch [5/200], Loss: 0.5437, Accuracy: 0.8083
# Epoch [6/200], Loss: 0.4993, Accuracy: 0.8280
# Epoch [7/200], Loss: 0.4730, Accuracy: 0.8340
# Epoch [8/200], Loss: 0.4449, Accuracy: 0.8439
# Epoch [9/200], Loss: 0.4177, Accuracy: 0.8544
# Epoch [10/200], Loss: 0.4000, Accuracy: 0.8602
# Epoch [11/200], Loss: 0.3778, Accuracy: 0.8661
# Epoch [12/200], Loss: 0.3630, Accuracy: 0.8737
# Epoch [13/200], Loss: 0.3422, Accuracy: 0.8791
# Epoch [14/200], Loss: 0.3303, Accuracy: 0.8826
# Epoch [15/200], Loss: 0.3173, Accuracy: 0.8908
# Epoch [16/200], Loss: 0.2990, Accuracy: 0.8944
# Epoch [17/200], Loss: 0.2891, Accuracy: 0.8979
# Epoch [18/200], Loss: 0.2801, Accuracy: 0.9023
# Epoch [19/200], Loss: 0.2703, Accuracy: 0.9038
# Epoch [20/200], Loss: 0.2600, Accuracy: 0.9085
# Epoch [21/200], Loss: 0.2430, Accuracy: 0.9144
# Epoch [22/200], Loss: 0.2354, Accuracy: 0.9184
# Epoch [23/200], Loss: 0.2280, Accuracy: 0.9191
# Epoch [24/200], Loss: 0.2208, Accuracy: 0.9223
# Epoch [25/200], Loss: 0.2085, Accuracy: 0.9265
# Epoch [26/200], Loss: 0.2006, Accuracy: 0.9287
# Epoch [27/200], Loss: 0.1986, Accuracy: 0.9288
# Epoch [28/200], Loss: 0.1822, Accuracy: 0.9354
# Epoch [29/200], Loss: 0.1846, Accuracy: 0.9352
# Epoch [30/200], Loss: 0.1767, Accuracy: 0.9366
# Epoch [31/200], Loss: 0.1681, Accuracy: 0.9396
# Epoch [32/200], Loss: 0.1629, Accuracy: 0.9420
# Epoch [33/200], Loss: 0.1554, Accuracy: 0.9451
# Epoch [34/200], Loss: 0.1541, Accuracy: 0.9454
# Epoch [35/200], Loss: 0.1470, Accuracy: 0.9475
# Epoch [36/200], Loss: 0.1398, Accuracy: 0.9502
# Epoch [37/200], Loss: 0.1363, Accuracy: 0.9518
# Epoch [38/200], Loss: 0.1346, Accuracy: 0.9522
# Epoch [39/200], Loss: 0.1302, Accuracy: 0.9544
# Epoch [40/200], Loss: 0.1268, Accuracy: 0.9547
# Epoch [41/200], Loss: 0.1217, Accuracy: 0.9570
# Epoch [42/200], Loss: 0.1134, Accuracy: 0.9597
# Epoch [43/200], Loss: 0.1148, Accuracy: 0.9592
# Epoch [44/200], Loss: 0.1081, Accuracy: 0.9615
# Epoch [45/200], Loss: 0.1036, Accuracy: 0.9636
# Epoch [46/200], Loss: 0.1042, Accuracy: 0.9631
# Epoch [47/200], Loss: 0.1005, Accuracy: 0.9650
# Epoch [48/200], Loss: 0.0977, Accuracy: 0.9654
# Epoch [49/200], Loss: 0.0928, Accuracy: 0.9668
# Epoch [50/200], Loss: 0.0891, Accuracy: 0.9691
# Epoch [51/200], Loss: 0.0866, Accuracy: 0.9685
# Epoch [52/200], Loss: 0.0903, Accuracy: 0.9685
# Epoch [53/200], Loss: 0.0853, Accuracy: 0.9693
# Epoch [54/200], Loss: 0.0820, Accuracy: 0.9716
# Epoch [55/200], Loss: 0.0798, Accuracy: 0.9717
# Epoch [56/200], Loss: 0.0756, Accuracy: 0.9738
# Epoch [57/200], Loss: 0.0786, Accuracy: 0.9729
# Epoch [58/200], Loss: 0.0770, Accuracy: 0.9738
# Epoch [59/200], Loss: 0.0749, Accuracy: 0.9733
# Epoch [60/200], Loss: 0.0713, Accuracy: 0.9749
# Epoch [61/200], Loss: 0.0665, Accuracy: 0.9769
# Epoch [62/200], Loss: 0.0655, Accuracy: 0.9769
# Epoch [63/200], Loss: 0.0642, Accuracy: 0.9777
# Epoch [64/200], Loss: 0.0660, Accuracy: 0.9779
# Epoch [65/200], Loss: 0.0620, Accuracy: 0.9787
# Epoch [66/200], Loss: 0.0609, Accuracy: 0.9783
# Epoch [67/200], Loss: 0.0622, Accuracy: 0.9775
# Epoch [68/200], Loss: 0.0586, Accuracy: 0.9789
# Epoch [69/200], Loss: 0.0574, Accuracy: 0.9809
# Epoch [70/200], Loss: 0.0582, Accuracy: 0.9789
# Epoch [71/200], Loss: 0.0528, Accuracy: 0.9811
# Epoch [72/200], Loss: 0.0520, Accuracy: 0.9816
# Epoch [73/200], Loss: 0.0550, Accuracy: 0.9810
# Epoch [74/200], Loss: 0.0498, Accuracy: 0.9828
# Epoch [75/200], Loss: 0.0499, Accuracy: 0.9826
# Epoch [76/200], Loss: 0.0518, Accuracy: 0.9818
# Epoch [77/200], Loss: 0.0479, Accuracy: 0.9838
# Epoch [78/200], Loss: 0.0483, Accuracy: 0.9837
# Epoch [79/200], Loss: 0.0484, Accuracy: 0.9834
# Epoch [80/200], Loss: 0.0448, Accuracy: 0.9848
# Epoch [81/200], Loss: 0.0430, Accuracy: 0.9851
# Epoch [82/200], Loss: 0.0470, Accuracy: 0.9838
# Epoch [83/200], Loss: 0.0464, Accuracy: 0.9836
# Epoch [84/200], Loss: 0.0419, Accuracy: 0.9857
# Epoch [85/200], Loss: 0.0430, Accuracy: 0.9854
# Epoch [86/200], Loss: 0.0429, Accuracy: 0.9846
# Epoch [87/200], Loss: 0.0411, Accuracy: 0.9859
# Epoch [88/200], Loss: 0.0420, Accuracy: 0.9859
# Epoch [89/200], Loss: 0.0393, Accuracy: 0.9860
# Epoch [90/200], Loss: 0.0390, Accuracy: 0.9862
# Epoch [91/200], Loss: 0.0373, Accuracy: 0.9876
# Epoch [92/200], Loss: 0.0398, Accuracy: 0.9863
# Epoch [93/200], Loss: 0.0343, Accuracy: 0.9879
# Epoch [94/200], Loss: 0.0374, Accuracy: 0.9875
# Epoch [95/200], Loss: 0.0368, Accuracy: 0.9871
# Epoch [96/200], Loss: 0.0338, Accuracy: 0.9880
# Epoch [97/200], Loss: 0.0355, Accuracy: 0.9885
# Epoch [98/200], Loss: 0.0309, Accuracy: 0.9891
# Epoch [99/200], Loss: 0.0349, Accuracy: 0.9875
# Epoch [100/200], Loss: 0.0322, Accuracy: 0.9892
# Epoch [101/200], Loss: 0.0324, Accuracy: 0.9888
# Epoch [102/200], Loss: 0.0319, Accuracy: 0.9896
# Epoch [103/200], Loss: 0.0297, Accuracy: 0.9901
# Epoch [104/200], Loss: 0.0303, Accuracy: 0.9898
# Epoch [105/200], Loss: 0.0321, Accuracy: 0.9897
# Epoch [106/200], Loss: 0.0326, Accuracy: 0.9887
# Epoch [107/200], Loss: 0.0313, Accuracy: 0.9895
# Epoch [108/200], Loss: 0.0323, Accuracy: 0.9890
# Epoch [109/200], Loss: 0.0333, Accuracy: 0.9882
# Epoch [110/200], Loss: 0.0290, Accuracy: 0.9898
# Epoch [111/200], Loss: 0.0292, Accuracy: 0.9897
# Epoch [112/200], Loss: 0.0260, Accuracy: 0.9911
# Epoch [113/200], Loss: 0.0279, Accuracy: 0.9904
# Epoch [114/200], Loss: 0.0260, Accuracy: 0.9909
# Epoch [115/200], Loss: 0.0270, Accuracy: 0.9909
# Epoch [116/200], Loss: 0.0247, Accuracy: 0.9917
# Epoch [117/200], Loss: 0.0262, Accuracy: 0.9907
# Epoch [118/200], Loss: 0.0280, Accuracy: 0.9909
# Epoch [119/200], Loss: 0.0256, Accuracy: 0.9908
# Epoch [120/200], Loss: 0.0250, Accuracy: 0.9916
# Epoch [121/200], Loss: 0.0237, Accuracy: 0.9922
# Epoch [122/200], Loss: 0.0269, Accuracy: 0.9907
# Epoch [123/200], Loss: 0.0260, Accuracy: 0.9906
# Epoch [124/200], Loss: 0.0261, Accuracy: 0.9908
# Epoch [125/200], Loss: 0.0234, Accuracy: 0.9920
# Epoch [126/200], Loss: 0.0246, Accuracy: 0.9916
# Epoch [127/200], Loss: 0.0233, Accuracy: 0.9924
# Epoch [128/200], Loss: 0.0247, Accuracy: 0.9916
# Epoch [129/200], Loss: 0.0238, Accuracy: 0.9918
# Epoch [130/200], Loss: 0.0240, Accuracy: 0.9919
# Epoch [131/200], Loss: 0.0221, Accuracy: 0.9923
# Epoch [132/200], Loss: 0.0229, Accuracy: 0.9920
# Epoch [133/200], Loss: 0.0244, Accuracy: 0.9914
# Epoch [134/200], Loss: 0.0235, Accuracy: 0.9920
# Epoch [135/200], Loss: 0.0231, Accuracy: 0.9922
# Epoch [136/200], Loss: 0.0212, Accuracy: 0.9926
# Epoch [137/200], Loss: 0.0214, Accuracy: 0.9928
# Epoch [138/200], Loss: 0.0202, Accuracy: 0.9934
# Epoch [139/200], Loss: 0.0204, Accuracy: 0.9934
# Epoch [140/200], Loss: 0.0204, Accuracy: 0.9931
# Epoch [141/200], Loss: 0.0209, Accuracy: 0.9932
# Epoch [142/200], Loss: 0.0197, Accuracy: 0.9936
# Epoch [143/200], Loss: 0.0198, Accuracy: 0.9935
# Epoch [144/200], Loss: 0.0188, Accuracy: 0.9934
# Epoch [145/200], Loss: 0.0191, Accuracy: 0.9933
# Epoch [146/200], Loss: 0.0182, Accuracy: 0.9940
# Epoch [147/200], Loss: 0.0201, Accuracy: 0.9927
# Epoch [148/200], Loss: 0.0189, Accuracy: 0.9937
# Epoch [149/200], Loss: 0.0184, Accuracy: 0.9939
# Epoch [150/200], Loss: 0.0181, Accuracy: 0.9938
# Epoch [151/200], Loss: 0.0187, Accuracy: 0.9937
# Epoch [152/200], Loss: 0.0184, Accuracy: 0.9940
# Epoch [153/200], Loss: 0.0159, Accuracy: 0.9948
# Epoch [154/200], Loss: 0.0175, Accuracy: 0.9944
# Epoch [155/200], Loss: 0.0192, Accuracy: 0.9936
# Epoch [156/200], Loss: 0.0167, Accuracy: 0.9943
# Epoch [157/200], Loss: 0.0169, Accuracy: 0.9941
# Epoch [158/200], Loss: 0.0185, Accuracy: 0.9941
# Epoch [159/200], Loss: 0.0155, Accuracy: 0.9948
# Epoch [160/200], Loss: 0.0164, Accuracy: 0.9944
# Epoch [161/200], Loss: 0.0159, Accuracy: 0.9946
# Epoch [162/200], Loss: 0.0159, Accuracy: 0.9949
# Epoch [163/200], Loss: 0.0174, Accuracy: 0.9940
# Epoch [164/200], Loss: 0.0170, Accuracy: 0.9942
# Epoch [165/200], Loss: 0.0162, Accuracy: 0.9946
# Epoch [166/200], Loss: 0.0156, Accuracy: 0.9943
# Epoch [167/200], Loss: 0.0146, Accuracy: 0.9952
# Epoch [168/200], Loss: 0.0167, Accuracy: 0.9943
# Epoch [169/200], Loss: 0.0158, Accuracy: 0.9947
# Epoch [170/200], Loss: 0.0158, Accuracy: 0.9947
# Epoch [171/200], Loss: 0.0167, Accuracy: 0.9944
# Epoch [172/200], Loss: 0.0161, Accuracy: 0.9946
# Epoch [173/200], Loss: 0.0157, Accuracy: 0.9952
# Epoch [174/200], Loss: 0.0165, Accuracy: 0.9945
# Epoch [175/200], Loss: 0.0141, Accuracy: 0.9952
# Epoch [176/200], Loss: 0.0147, Accuracy: 0.9953
# Epoch [177/200], Loss: 0.0149, Accuracy: 0.9947
# Epoch [178/200], Loss: 0.0151, Accuracy: 0.9948
# Epoch [179/200], Loss: 0.0151, Accuracy: 0.9947
# Epoch [180/200], Loss: 0.0146, Accuracy: 0.9951
# Epoch [181/200], Loss: 0.0139, Accuracy: 0.9955
# Epoch [182/200], Loss: 0.0136, Accuracy: 0.9955
# Epoch [183/200], Loss: 0.0133, Accuracy: 0.9954
# Epoch [184/200], Loss: 0.0145, Accuracy: 0.9951
# Epoch [185/200], Loss: 0.0138, Accuracy: 0.9956
# Epoch [186/200], Loss: 0.0135, Accuracy: 0.9954
# Epoch [187/200], Loss: 0.0129, Accuracy: 0.9955
# Epoch [188/200], Loss: 0.0137, Accuracy: 0.9954
# Epoch [189/200], Loss: 0.0132, Accuracy: 0.9952
# Epoch [190/200], Loss: 0.0152, Accuracy: 0.9952
# Epoch [191/200], Loss: 0.0144, Accuracy: 0.9953
# Epoch [192/200], Loss: 0.0152, Accuracy: 0.9949
# Epoch [193/200], Loss: 0.0139, Accuracy: 0.9954
# Epoch [194/200], Loss: 0.0157, Accuracy: 0.9947
# Epoch [195/200], Loss: 0.0143, Accuracy: 0.9956
# Epoch [196/200], Loss: 0.0132, Accuracy: 0.9958
# Epoch [197/200], Loss: 0.0120, Accuracy: 0.9960
# Epoch [198/200], Loss: 0.0129, Accuracy: 0.9958
# Epoch [199/200], Loss: 0.0139, Accuracy: 0.9954
# Epoch [200/200], Loss: 0.0124, Accuracy: 0.9959
# Training finished!

# %% [markdown]
# # Plotting Accuracy and Loss

# %%
figure, axis = plt.subplots(1, 2,figsize=(20,8))
axis[0].plot(history['epochs'],history['val_loss'])
axis[0].plot(history['epochs'],history['train_loss'])
axis[0].set_xticks(range(10))
axis[0].set_xlabel("Epochs")
axis[1].set_ylabel("Accuracy")
axis[0].set_ylim([0, 1.5])
axis[0].set_title("Loss")
axis[1].plot(history['epochs'],history['val_acc'])
axis[1].plot(history['epochs'],history['train_acc'])
axis[1].set_xlabel("Epochs")
axis[0].set_ylabel("Loss")
axis[1].set_title("Accuracy")
axis[1].set_ylim([0, 1])
axis[1].set_xticks(range(10))
figure.legend(["Val", "Train"], loc='upper right')

# %%
tresh= 0.754
total_count=0
ratio=0
model.eval()
total_count=0
with torch.no_grad():
  for x ,y in test_dataloader:
    x = x.to(device)
    this= model(x)
    probabilities = nn.Softmax(dim=1)(this)
    max_prob, predicted = torch.max(probabilities, dim=1)
    #max_prob, predicted = torch.max(this, dim=1)
    count = sum(1 for num in max_prob if num > tresh)
    total_count=count+total_count
ratio=total_count/len(test_dataloader.dataset)
print(f'ratio of inliers predicted by the model: {ratio}')
# Out:
# ratio of inliers predicted by the model: 0.9503333333333334

# %%
tresh= 0.754
total_count=0
ratio=0
model.eval()
total_count=0
with torch.no_grad():
  for x ,y in cat_test_dataloader:
    x = x.to(device)
    this= model(x)
    probabilities = nn.Softmax(dim=1)(this)
    max_prob, predicted = torch.max(probabilities, dim=1)
    #max_prob, predicted = torch.max(this, dim=1)
    count = sum(1 for num in max_prob if num > tresh)
    total_count=count+total_count
ratio=total_count/len(cat_test_dataloader.dataset)
print(f'ratio of inliers predicted by the model for the cat class: {ratio}')
# Out:
# ratio of inliers predicted by the model for the cat class: 0.826
